# %% [markdown]
# <a href="https://colab.research.google.com/github/GomesFM/SKILLS_DEVELOPMENT/blob/main/Energia%20Nuclear/Nuclear_franca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/usinas_nucleares.csv')
dados
# Out:
#                  country_long                           name   gppd_idnr  \
# 0                   Argentina                       ATUCHA I  ARG0000029
# 1                   Argentina                      ATUCHA II  ARG0000030
# 2                   Argentina                        EMBALSE  ARG0000112
# 3                     Armenia                     Armenian-2  WRI1019028
# 4                     Belgium                         DOEL 4  WRI1002223
# ..                        ...                            ...         ...
# 190  United States of America                     V C Summer  USA0006127
# 191  United States of America                         Vogtle  USA0000649
# 192  United States of America                    Waterford 3  USA0004270
# 193  United States of America        Watts Bar Nuclear Plant  USA0007722
# 194  United States of America  Wolf Creek Generating Station  USA0000210
#
#      capacity_mw  latitude  longitude  commissioning_year  \
# ...

# %%
dados['country_long'].unique()
# Out:
# array(['Argentina', 'Armenia', 'Belgium', 'Brazil', 'Bulgaria', 'Canada',
#        'China', 'Czech Republic', 'Finland', 'France', 'Germany',
#        'Hungary', 'India', 'Iran', 'Japan', 'Mexico', 'Netherlands',
#        'Pakistan', 'Romania', 'Russia', 'Slovakia', 'Slovenia',
#        'South Africa', 'South Korea', 'Spain', 'Sweden', 'Switzerland',
#        'Taiwan', 'Ukraine', 'United Kingdom', 'United States of America'],
#       dtype=object)

# %%
dados_franca = dados[dados['country_long'] == 'France'].copy()

# %%
dados_franca
# Out:
#    country_long         name   gppd_idnr  capacity_mw  latitude  longitude  \
# 32       France   BELLEVILLE  WRI1002693       2620.0   47.5103     2.8750
# 33       France      BLAYAIS  WRI1002694       3640.0   45.2560    -0.6932
# 34       France        BUGEY  WRI1002701       3580.0   45.7973     5.2706
# 35       France     CATTENOM  WRI1002703       5200.0   49.4160     6.2169
# 36       France       CHINON  WRI1002706       3620.0   47.2254     0.1656
# 37       France        CHOOZ  WRI1002707       3000.0   50.0900     4.7894
# 38       France       CIVAUX  WRI1002708       2990.0   46.4563     0.6548
# 39       France        CRUAS  WRI1002716       3660.0   44.6325     4.7546
# 40       France    DAMPIERRE  WRI1002720       3560.0   47.7321     2.5185
# 41       France   FESSENHEIM  WRI1002727       1760.0   47.9032     7.5631
# 42       France  FLAMANVILLE  WRI1002728       2660.0   49.5366    -1.8823
# ...

# %%
colunas = ['country_long', 'commissioning_year']

# %%
dados_franca.drop(columns = colunas, inplace=True)
dados_franca
# Out:
#            name   gppd_idnr  capacity_mw  latitude  longitude  \
# 32   BELLEVILLE  WRI1002693       2620.0   47.5103     2.8750
# 33      BLAYAIS  WRI1002694       3640.0   45.2560    -0.6932
# 34        BUGEY  WRI1002701       3580.0   45.7973     5.2706
# 35     CATTENOM  WRI1002703       5200.0   49.4160     6.2169
# 36       CHINON  WRI1002706       3620.0   47.2254     0.1656
# 37        CHOOZ  WRI1002707       3000.0   50.0900     4.7894
# 38       CIVAUX  WRI1002708       2990.0   46.4563     0.6548
# 39        CRUAS  WRI1002716       3660.0   44.6325     4.7546
# 40    DAMPIERRE  WRI1002720       3560.0   47.7321     2.5185
# 41   FESSENHEIM  WRI1002727       1760.0   47.9032     7.5631
# 42  FLAMANVILLE  WRI1002728       2660.0   49.5366    -1.8823
# 43      GOLFECH  WRI1002733       2620.0   44.1060     0.8443
# 44   GRAVELINES  WRI1002735       5460.0   51.0141     2.1332
# 45       NOGENT  WRI1002749       2620.0   48.5171     3.5181
# ...

# %%
dados_franca.drop(41, axis=0, inplace=True)

# %%
dados_franca.to_csv('nucleares_franca.csv', index=False)
